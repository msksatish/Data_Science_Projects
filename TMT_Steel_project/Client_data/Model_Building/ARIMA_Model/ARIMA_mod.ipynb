# %% [markdown]
# ## ARIMA Model

# %%
import pandas as pd
import statsmodels.graphics.tsaplots as tsa_plots
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot

# %%
df = pd.read_csv(r"C:\Users\MsK_PC\360digiTMG\Data_Science\DS_TMT_Steel_Project\Client_data\12mm.csv")

# %%
df= df.drop(['t','t_square','log_Quantity','April','August','December','February','January','July','June','March','May','November','October','September'], axis=1)

# %%
df
# Out:
#             Date    dia  Quantity      Rate     Value
# 0     2017-04-03  12 MM      1.93  41200.00   79516.0
# 1     2017-04-04  12 MM     10.19  37976.19  555690.0
# 2     2017-04-06  12 MM     10.19  41500.00  555690.0
# 3     2017-04-06  12 MM      3.03  41000.00  124230.0
# 4     2017-04-07  12 MM      5.15  40800.00  210120.0
# ...          ...    ...       ...       ...       ...
# 6552  2023-03-07  12 MM      9.98  61950.00  555690.0
# 6553  2023-03-10  12 MM     10.19  63200.00  555690.0
# 6554  2023-03-23  12 MM      2.09  60400.00  126236.0
# 6555  2023-03-25  12 MM      8.66  60000.00  519600.0
# 6556  2023-03-30  12 MM     -3.01  59000.00 -206150.0
#
# [6557 rows x 5 columns]

# %%
#'Quantity' column will have aggregated sums for the same date


# Assuming your data is stored in a DataFrame called 'df'
aggregated_df = df.groupby('Date')['Quantity'].sum().reset_index()

# 'aggregated_df' will contain the sum of quantities for each unique date in a single row

aggregated_df
# Out:
#             Date  Quantity
# 0     2017-04-03      1.93
# 1     2017-04-04     10.19
# 2     2017-04-06     13.22
# 3     2017-04-07     15.34
# 4     2017-04-08     15.29
# ...          ...       ...
# 1609  2023-03-25     16.10
# 1610  2023-03-28     11.17
# 1611  2023-03-29      5.18
# 1612  2023-03-30     25.49
# 1613  2023-03-31      9.15
#
# [1614 rows x 2 columns]

# %%
# Data Partition
#Train = df.head(6545)
#Test = df.tail(12)

# Data Partition
Train = aggregated_df.iloc[:len(aggregated_df)-365]
Test = aggregated_df.iloc[len(aggregated_df)-365:]

# %%
Test
# Out:
#             Date  Quantity
# 1249  2021-12-07      9.22
# 1250  2021-12-08      8.36
# 1251  2021-12-09     13.92
# 1252  2021-12-10     25.07
# 1253  2021-12-11      3.45
# ...          ...       ...
# 1609  2023-03-25     16.10
# 1610  2023-03-28     11.17
# 1611  2023-03-29      5.18
# 1612  2023-03-30     25.49
# 1613  2023-03-31      9.15
#
# [365 rows x 2 columns]

# %%
tsa_plots.plot_acf(df.Quantity, lags = 12)
tsa_plots.plot_pacf(df.Quantity, lags = 12)

# %%
# ARIMA with AR = 12, MA = 6
model1 = ARIMA(Train.Quantity, order = (12, 2, 3))
res1 = model1.fit()
print(res1.summary())
# Out:
# C:\Users\MsK_PC\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\MsK_PC\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\MsK_PC\anaconda3\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               Quantity   No. Observations:                 1249
# Model:                ARIMA(12, 2, 3)   Log Likelihood               -4902.469
# Date:                Fri, 01 Sep 2023   AIC                           9836.937
# Time:                        13:10:11   BIC                           9918.993
# Sample:                             0   HQIC                          9867.789
#                                - 1249
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -2.4629      0.107    -22.964      0.000      -2.673      -2.253
# ar.L2         -2.7216      0.197    -13.803      0.000      -3.108      -2.335
# ar.L3         -2.1401      0.175    -12.236      0.000      -2.483      -1.797
# ar.L4         -1.8425      0.165    -11.166      0.000      -2.166      -1.519
# ar.L5         -1.6222      0.167     -9.712      0.000      -1.950      -1.295
# ar.L6         -1.3167      0.165     -7.960      0.000      -1.641      -0.992
# ar.L7         -1.0339      0.157     -6.584      0.000      -1.342      -0.726
# ar.L8         -0.8156      0.144     -5.680      0.000      -1.097      -0.534
# ar.L9         -0.6271      0.127     -4.931      0.000      -0.876      -0.378
# ar.L10        -0.4609      0.109     -4.211      0.000      -0.675      -0.246
# ar.L11        -0.2831      0.077     -3.698      0.000      -0.433      -0.133
# ar.L12        -0.0971      0.030     -3.280      0.001      -0.155      -0.039
# ma.L1          0.6916      0.310      2.232      0.026       0.084       1.299
# ma.L2         -0.8471      0.512     -1.655      0.098      -1.850       0.156
# ma.L3         -0.8441      0.283     -2.980      0.003      -1.399      -0.289
# sigma2       150.9069     46.289      3.260      0.001      60.182     241.632
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):               109.09
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.72   Skew:                             0.65
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast for next 365 days
start_index = len(Train)
start_index
end_index = start_index + 364
forecast_test = res1.predict(start = start_index, end = end_index)

print(forecast_test)
# Out:
# 1249    9.579847
# 1250    8.422287
# 1251    9.850326
# 1252    8.524736
# 1253    8.432910
#           ...
# 1609    7.699643
# 1610    7.696728
# 1611    7.693813
# 1612    7.690898
# 1613    7.687983
# Name: predicted_mean, Length: 365, dtype: float64

# %%
# Evaluate forecasts
rmse_test = sqrt(mean_squared_error(Test.Quantity, forecast_test))
print('Test RMSE: %.3f' % rmse_test)
# Out:
# Test RMSE: 12.301

# %%
Test.Quantity
# Out:
# 1249     9.22
# 1250     8.36
# 1251    13.92
# 1252    25.07
# 1253     3.45
#         ...
# 1609    16.10
# 1610    11.17
# 1611     5.18
# 1612    25.49
# 1613     9.15
# Name: Quantity, Length: 365, dtype: float64

# %%
# plot forecasts against actual outcomes
pyplot.plot(Test.Quantity)
pyplot.plot(forecast_test, color = 'red')
pyplot.show()

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp310-cp310-win_amd64.whl (569 kB)
#      -------------------------------------- 569.7/569.7 kB 4.0 MB/s eta 0:00:00
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-3.0.2-cp310-cp310-win_amd64.whl (2.8 MB)
#      ---------------------------------------- 2.8/2.8 MB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in c:\users\msk_pc\anaconda3\lib\site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: pandas>=0.19 in c:\users\msk_pc\anaconda3\lib\site-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\msk_pc\anaconda3\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\msk_pc\anaconda3\lib\site-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: joblib>=0.11 in c:\users\msk_pc\anaconda3\lib\site-packages (from pmdarima) (1.3.1)
# Requirement already satisfied: urllib3 in c:\users\msk_pc\anaconda3\lib\site-packages (from pmdarima) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\msk_pc\anaconda3\lib\site-packages (from pmdarima) (65.6.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\msk_pc\anaconda3\lib\site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\msk_pc\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msk_pc\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msk_pc\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\msk_pc\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\msk_pc\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\msk_pc\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (23.0)
# Requirement already satisfied: six in c:\users\msk_pc\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.2 pmdarima-2.0.3
# WARNING: Ignoring invalid distribution -cipy (c:\users\msk_pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\msk_pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\msk_pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\msk_pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\msk_pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\msk_pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\msk_pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\msk_pc\anaconda3\lib\site-packages)

# %%
# Auto-ARIMA - Automatically discover the optimal order for an ARIMA model.
# pip install pmdarima --user
import pmdarima as pm

#help(pm.auto_arima)

ar_model = pm.auto_arima(Train.Quantity, start_p = 0, start_q = 0,
                      max_p = 30, max_q = 12, # maximum p and q
                      m = 12,              # frequency of series
                      d = None,           # let model determine 'd'
                      seasonal = True,   # Seasonality
                      start_P = 0, trace = True,
                      error_action = 'warn', stepwise = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=10416.467, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=10414.643, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=10068.069, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=9784.510, Time=0.76 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=10412.643, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=9784.890, Time=0.18 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=9786.066, Time=1.20 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=9785.947, Time=2.52 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=9784.414, Time=0.58 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=9785.954, Time=1.94 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=9787.954, Time=2.54 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=10416.471, Time=0.16 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=9764.923, Time=1.46 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=9763.088, Time=0.45 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=9764.930, Time=1.44 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=9766.727, Time=4.00 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=10066.324, Time=0.13 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=9769.653, Time=0.35 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=9993.270, Time=0.19 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=9761.516, Time=0.23 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=9763.260, Time=0.52 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=9763.270, Time=0.68 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=9765.061, Time=1.69 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=9782.955, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=10064.324, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=inf, Time=0.32 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=inf, Time=0.51 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=9767.832, Time=0.14 sec
#  ARIMA(2,1,0)(0,0,0)[12]             : AIC=9991.270, Time=0.10 sec
#  ARIMA(2,1,2)(0,0,0)[12]             : AIC=inf, Time=0.46 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[12]
# Total fit time: 25.796 seconds

# %%
# Best Parameters ARIMA
model = ARIMA(Train.Quantity, order = (1, 1, 1))
res = model.fit()
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               Quantity   No. Observations:                 1249
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -4877.758
# Date:                Fri, 01 Sep 2023   AIC                           9761.516
# Time:                        13:54:17   BIC                           9776.904
# Sample:                             0   HQIC                          9767.301
#                                - 1249
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1631      0.029      5.686      0.000       0.107       0.219
# ma.L1         -0.9854      0.005   -182.069      0.000      -0.996      -0.975
# sigma2       144.9630      4.855     29.858      0.000     135.447     154.479
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.58   Jarque-Bera (JB):               231.13
# Prob(Q):                              0.45   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.76   Skew:                             0.95
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast for next 365 days
start_index = len(Train)
end_index = start_index + 364
forecast_best = res.predict(start = start_index, end = end_index)


print(forecast_best)
# Out:
# 1249    13.286250
# 1250    13.597217
# 1251    13.647945
# 1252    13.656220
# 1253    13.657570
#           ...
# 1609    13.657833
# 1610    13.657833
# 1611    13.657833
# 1612    13.657833
# 1613    13.657833
# Name: predicted_mean, Length: 365, dtype: float64

# %%
# Evaluate forecasts
rmse_best = sqrt(mean_squared_error(Test.Quantity, forecast_best))
print('Test RMSE: %.3f' % rmse_best)
# plot forecasts against actual outcomes
pyplot.plot(Test.Quantity)
pyplot.plot(forecast_best, color = 'red')
pyplot.show()
# Out:
# Test RMSE: 10.899

# %%
from scipy.stats import ks_2samp
# Calculate Kolmogorov-Smirnov statistic for model drift detection
ks_statistic, ks_p_value = ks_2samp(Test['Quantity'], forecast_best)

# Define a threshold for significance level
threshold = 0.05

# Check for model drift based on p-value
model_drift_detected = ks_p_value < threshold
# Display model drift detection result
print("Model Drift Detected:", model_drift_detected)
# Out:
# Model Drift Detected: True
