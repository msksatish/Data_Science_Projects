# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Define the number of rows
num_rows = 20000

# Create a DataFrame with the specified columns and data types
data = {
    'Timestamp': [datetime(2023, 10, 13, 8, 30) + timedelta(minutes=random.randint(1, 1440)) for _ in range(num_rows)],
    'Material Type': [random.choice(['Sand', 'Gravel', 'Cement']) for _ in range(num_rows)],
    'Production Rate': [round(random.uniform(10, 100), 1) for _ in range(num_rows)],
    'Machine Status': [random.choice([True, False]) for _ in range(num_rows)],
    'Downtime Duration': [timedelta(hours=random.randint(1, 12), minutes=random.randint(0, 59)) for _ in range(num_rows)],
    'Raw Material Inventory': [round(random.uniform(500, 1500), 1) for _ in range(num_rows)],
    'Product Inventory': [round(random.uniform(300, 700), 1) for _ in range(num_rows)],
    'Revenue Loss': [round(random.uniform(1000, 10000), 2) for _ in range(num_rows)],
    'Demand Forecast': [random.randint(800, 1200) for _ in range(num_rows)],
    'Actual Production': [random.randint(700, 1100) for _ in range(num_rows)],
    'Reject Rate': [round(random.uniform(2.0, 8.0), 2) for _ in range(num_rows)],
    'Maintenance Log': ['Maintenance description ' + str(i) for i in range(num_rows)],
    'Employee Productivity': [round(random.uniform(0, 1), 2) for _ in range(num_rows)],
    'Energy Consumption': [round(random.uniform(800, 1200), 1) for _ in range(num_rows)],
    'Temperature': [round(random.uniform(18, 23), 1) for _ in range(num_rows)],
    'Humidity': [random.randint(40, 80) for _ in range(num_rows)],
    'Supplier Performance': [random.choice(['Good', 'Fair', 'Poor']) for _ in range(num_rows)],
    'Order Fulfillment': [random.randint(80, 100) for _ in range(num_rows)],
    'Cost of Raw Materials': [round(random.uniform(8000, 12000), 2) for _ in range(num_rows)],
    'Quality Control Alarms': [random.randint(0, 5) for _ in range(num_rows)],
    'Quality': [random.choice(['High', 'Medium', 'Low']) for _ in range(num_rows)],
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('sample_data.csv', index=False)

# %%
import pandas as pd
import numpy as np

# Define the number of rows for your dataset
num_rows = 3000

# Create a dictionary to store data for each column
data = {
    'Blaine': np.random.uniform(300, 500, num_rows),
    'C3A': np.random.uniform(0.1, 2.0, num_rows),
    'C4AF': np.random.uniform(0.1, 2.0, num_rows),
    'G-SO3': np.random.uniform(0.1, 2.0, num_rows),
    'G-Moisture': np.random.uniform(1.0, 5.0, num_rows),
    'FA-Blaine': np.random.uniform(200, 400, num_rows),
    'Gypsum Weigh Feeder_TPH': np.random.uniform(10, 50, num_rows),
    'Fly Ash SFF_TPH': np.random.uniform(10, 50, num_rows),
    'Drive Power_MILL_KW': np.random.uniform(100, 300, num_rows),
    'Separator_speed_RPM': np.random.uniform(1000, 2000, num_rows),
    'Position_Master Roller1_mm': np.random.uniform(0, 100, num_rows),
    'Counter Pressure_HLSM_mm': np.random.uniform(0, 50, num_rows),
    'Hydraulic_pressure': np.random.uniform(20, 80, num_rows),
    'Fan Power_Kw': np.random.uniform(50, 200, num_rows),
    'categorical__cem_type_Non Premium': np.random.choice([0, 1], num_rows),
    'categorical__cem_type_Premium': np.random.choice([0, 1], num_rows)
}

# Create a DataFrame from the generated data
df = pd.DataFrame(data)

# Display the first few rows of the generated data
print(df.head())
# Out:
#        Blaine       C3A      C4AF     G-SO3  G-Moisture   FA-Blaine  \
# 0  326.548390  0.395675  1.759285  0.928089    2.678260  217.450201
# 1  390.979756  0.193583  1.858194  1.658385    2.433602  239.417905
# 2  354.000548  1.208876  0.519774  0.963246    4.931361  272.785584
# 3  320.338565  0.966562  0.287209  1.759177    2.416035  295.239179
# 4  314.476760  1.157359  0.131103  1.564344    2.184492  357.794898
#
#    Gypsum Weigh Feeder_TPH  Fly Ash SFF_TPH  Drive Power_MILL_KW  \
# 0                46.814561        29.038762           172.895392
# 1                18.717748        21.286265           185.130930
# 2                23.950040        32.863195           191.576505
# 3                46.032143        29.255939           249.911216
# 4                38.573646        36.921919           245.322987
#
#    Separator_speed_RPM  Position_Master Roller1_mm  Counter Pressure_HLSM_mm  \
# 0          1240.889484                    0.947851                 19.737150
# 1          1803.500678                   39.883716                 27.505195
# 2          1023.854118                   96.099240                 29.030768
# 3          1944.569978                   23.450685                 10.617034
# 4          1087.928031                   51.992488                 42.547835
#
#    Hydraulic_pressure  Fan Power_Kw  categorical__cem_type_Non Premium  \
# 0           65.061260    107.561556                                  0
# 1           46.914414     52.333240                                  1
# 2           68.382005    117.137520                                  0
# 3           61.154327     91.639395                                  0
# 4           47.080731    175.695863                                  0
#
#    categorical__cem_type_Premium
# 0                              0
# 1                              1
# 2                              0
# 3                              1
# 4                              1

# %%
# Save the DataFrame to a CSV file
df.to_csv('new_data.csv', index=False)
